# %% [markdown]
# <h1><b> Automatidata NYC TLC Taxi Fare Estimation Project </b></h1>

# %% [markdown]
# <h3>Capstone Project: Google Advanced Data Analytics Professional Certificate</h3>

# %% [markdown]
# <h2><b> Background and Business Problem</b></h2>
# <p>
# The New York City Taxi and Limousine Commission (TLC) oversees the licensing and regulation of NYC's extensive taxi and for-hire vehicle network, managing over 200,000 licensees who collectively complete approximately one million trips daily. Currently, passengers and drivers lack accurate fare estimation capabilities before rides begin, creating several operational challenges:
#
# - **Passenger uncertainty**: Riders cannot reliably estimate trip costs in advance, leading to customer dissatisfaction and potential disputes
# - **Operational inefficiency**: Lack of predictable fare estimates affects trip planning and resource allocation
# - **Revenue optimization gaps**: TLC and taxi operators miss opportunities to optimize pricing strategies based on trip characteristics
# - **Regulatory oversight limitations**: Without predictive models, TLC cannot effectively analyze fare patterns for policy decisions
#
# To address these challenges, TLC has partnered with Automatidata to develop a robust regression model that accurately estimates taxi fares before rides commence, using historical trip data and relevant variables.</p>
#
# <h2><b>Business Impact</b></h2>
# <p>Implementing a predictive fare estimation model will deliver significant measurable business value:
# <ul>
#     <li><b>Enhanced customer experience:</b> Passengers will receive accurate fare estimates upfront, reducing uncertainty and improving satisfaction</li>
#     <li><b>Operational efficiency:</b> Drivers and dispatch systems can optimize route planning and trip acceptance based on estimated fares </li>
#     <li><b>Revenue optimization:</b> TLC and taxi operators can implement data-driven pricing strategies to maximize revenue while maintaining competitiveness</li>
#     <li><b>Regulatory insights:</b> TLC gains powerful analytical capabilities to monitor fare patterns, detect anomalies, and inform policy decisions</li>
#     <li><b>Market competitiveness:</b> Improved fare transparency helps traditional taxis compete more effectively with ride-sharing platforms</li>
# </ul>
#
# <h2><b>Methodology</b></h2>
# <h4>1) Data Collection and Preparation </h4>
# <ul>
#     <li> <b>Goal</b>: Construct comprehensive dataframes in Python, perform initial inspection of TLC's historical trip dataset, and communicate findings to stakeholders trip dataset, and communicate findings to stakeholders</li>
# <li><b>Understanding the situation:</b> How can the extensive TLC trip data (from 200,000+ licensees) be effectively organized and prepared for analysis? First we start by exploring the dataset. We will try to understand each variable within the dataset and their impact. To understand a bit more about the variable we can read fact sheet provided by company.
#  </li>
#  <li><b>Understand the data: </b>Create necessary dataframes to comprehend data structure, quality, and patterns for future exploratory data analysis (EDA) and statistical modeling</li>
#  <li><b>Understanding variables: </b>Leverage insights from summary statistics and data examination to guide deeper investigation into key fare-determining variables</li>
#
# </ul>

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt 
import plotly.express as px 
import warnings

warnings.filterwarnings("ignore")
df = pd.read_csv("2017_Yellow_Taxi_Trip_Data.csv")
df.head()
# Out:
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0    24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1    35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2   106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3    38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4    30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           100           231             1         13.0    0.0      0.5
# 1           186            43             1         16.0    0.0      0.5
# 2           262           236             1          6.5    0.0      0.5
# 3           188            97             1         20.5    0.0      0.5
# 4             4           112             2         16.5    0.5      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount
# 0        2.76           0.0                    0.3         16.56
# 1        4.00           0.0                    0.3         20.80
# 2        1.45           0.0                    0.3          8.75
# 3        6.39           0.0                    0.3         27.69
# 4        0.00           0.0                    0.3         17.80

# %%
df.head(10)
# Out:
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0    24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1    35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2   106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3    38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4    30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
# 5    23345809         2   03/25/2017 8:34:11 PM   03/25/2017 8:42:11 PM
# 6    37660487         2   05/03/2017 7:04:09 PM   05/03/2017 8:03:47 PM
# 7    69059411         2   08/15/2017 5:41:06 PM   08/15/2017 6:03:05 PM
# 8     8433159         2   02/04/2017 4:17:07 PM   02/04/2017 4:29:14 PM
# 9    95294817         1   11/10/2017 3:20:29 PM   11/10/2017 3:40:55 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# 1                1           1.80           1                  N
# 2                1           1.00           1                  N
# 3                1           3.70           1                  N
# 4                1           4.37           1                  N
# 5                6           2.30           1                  N
# 6                1          12.83           1                  N
# 7                1           2.98           1                  N
# 8                1           1.20           1                  N
# 9                1           1.60           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           100           231             1         13.0    0.0      0.5
# 1           186            43             1         16.0    0.0      0.5
# 2           262           236             1          6.5    0.0      0.5
# 3           188            97             1         20.5    0.0      0.5
# 4             4           112             2         16.5    0.5      0.5
# 5           161           236             1          9.0    0.5      0.5
# 6            79           241             1         47.5    1.0      0.5
# 7           237           114             1         16.0    1.0      0.5
# 8           234           249             2          9.0    0.0      0.5
# 9           239           237             1         13.0    0.0      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount
# 0        2.76           0.0                    0.3         16.56
# 1        4.00           0.0                    0.3         20.80
# 2        1.45           0.0                    0.3          8.75
# 3        6.39           0.0                    0.3         27.69
# 4        0.00           0.0                    0.3         17.80
# 5        2.06           0.0                    0.3         12.36
# 6        9.86           0.0                    0.3         59.16
# 7        1.78           0.0                    0.3         19.58
# 8        0.00           0.0                    0.3          9.80
# 9        2.75           0.0                    0.3         16.55

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
#  14  tip_amount             22699 non-null  float64
#  15  tolls_amount           22699 non-null  float64
#  16  improvement_surcharge  22699 non-null  float64
#  17  total_amount           22699 non-null  float64
# dtypes: float64(8), int64(7), object(3)
# memory usage: 3.1+ MB

# %% [markdown]
# <b> Key observations from above: </b>
# - There are 22699 rows and 17 columns.
# - There are no null values in any of the columns.
# - <b>tpep_pickup_datetime</b> and <b>tpep_dropoff_datetime</b> columns are not in datetime format.

# %%
df.describe()
# Out:
#          Unnamed: 0      VendorID  passenger_count  trip_distance  \
# count  2.269900e+04  22699.000000     22699.000000   22699.000000
# mean   5.675849e+07      1.556236         1.642319       2.913313
# std    3.274493e+07      0.496838         1.285231       3.653171
# min    1.212700e+04      1.000000         0.000000       0.000000
# 25%    2.852056e+07      1.000000         1.000000       0.990000
# 50%    5.673150e+07      2.000000         1.000000       1.610000
# 75%    8.537452e+07      2.000000         2.000000       3.060000
# max    1.134863e+08      2.000000         6.000000      33.960000
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean       1.043394    162.412353    161.527997      1.336887     13.026629
# std        0.708391     66.633373     70.139691      0.496211     13.243791
# min        1.000000      1.000000      1.000000      1.000000   -120.000000
# 25%        1.000000    114.000000    112.000000      1.000000      6.500000
# 50%        1.000000    162.000000    162.000000      1.000000      9.500000
# 75%        1.000000    233.000000    233.000000      2.000000     14.500000
# max       99.000000    265.000000    265.000000      4.000000    999.990000
#
#               extra       mta_tax    tip_amount  tolls_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000
# mean       0.333275      0.497445      1.835781      0.312542
# std        0.463097      0.039465      2.800626      1.399212
# min       -1.000000     -0.500000      0.000000      0.000000
# 25%        0.000000      0.500000      0.000000      0.000000
# 50%        0.000000      0.500000      1.350000      0.000000
# 75%        0.500000      0.500000      2.450000      0.000000
# max        4.500000      0.500000    200.000000     19.100000
#
#        improvement_surcharge  total_amount
# count           22699.000000  22699.000000
# mean                0.299551     16.310502
# std                 0.015673     16.097295
# min                -0.300000   -120.300000
# 25%                 0.300000      8.750000
# 50%                 0.300000     11.800000
# 75%                 0.300000     17.800000
# max                 0.300000   1200.290000

# %% [markdown]
# <b>Key obseravations from above: </b>
# - The <b>trip distance</b> for most rides is between 1 to 3 miles with the largest trip being over 33 miles. Trips with 0 miles need to be analyzed further.
# - The maximum <b>fare amount</b> is much higher than the 25-75 percent range of values. It is also odd that the minimum fare amount is a negative value. We will have to look at the distribution of the fare amount.
# - Similar observations can be observed with <b>total_amount</b> column.
# - The <b>passenger count</b> being 0 in some situation needs further analysis.
# - Payment type is categorical data and hence datatype need to be changed accordingly.

# %%
# sorting data by trip distance from longest trip to shortest trip 
df_sort = df.sort_values(by=['trip_distance'], ascending=False)
df_sort.head(10)
# Out:
#        Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 9280     51810714         2  06/18/2017 11:33:25 PM  06/19/2017 12:12:38 AM
# 13861    40523668         2   05/19/2017 8:20:21 AM   05/19/2017 9:20:30 AM
# 6064     49894023         2  06/13/2017 12:30:22 PM   06/13/2017 1:37:51 PM
# 10291    76319330         2  09/11/2017 11:41:04 AM  09/11/2017 12:18:58 PM
# 29       94052446         2   11/06/2017 8:30:50 PM  11/07/2017 12:00:00 AM
# 18130    90375786         1   10/26/2017 2:45:01 PM   10/26/2017 4:12:49 PM
# 5792     68023798         2   08/11/2017 2:14:01 PM   08/11/2017 3:17:31 PM
# 15350    77309977         2   09/14/2017 1:44:44 PM   09/14/2017 2:34:29 PM
# 10302    43431843         1   05/15/2017 8:11:34 AM   05/15/2017 9:03:16 AM
# 2592     51094874         2   06/16/2017 6:51:20 PM   06/16/2017 7:41:42 PM
#
#        passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 9280                 2          33.96           5                  N
# 13861                1          33.92           5                  N
# 6064                 1          32.72           3                  N
# 10291                1          31.95           4                  N
# 29                   1          30.83           1                  N
# 18130                1          30.50           1                  N
# 5792                 1          30.33           2                  N
# 15350                1          28.23           2                  N
# 10302                1          28.20           2                  N
# 2592                 1          27.97           2                  N
#
#        PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 9280            132           265             2       150.00    0.0      0.0
# 13861           229           265             1       200.01    0.0      0.5
# 6064            138             1             1       107.00    0.0      0.0
# 10291           138           265             2       131.00    0.0      0.5
# 29              132            23             1        80.00    0.5      0.5
# 18130           132           220             1        90.50    0.0      0.5
# 5792            132           158             1        52.00    0.0      0.5
# 15350            13           132             1        52.00    0.0      0.5
# 10302            90           132             1        52.00    0.0      0.5
# 2592            261           132             2        52.00    4.5      0.5
#
#        tip_amount  tolls_amount  improvement_surcharge  total_amount
# 9280         0.00          0.00                    0.3        150.30
# 13861       51.64          5.76                    0.3        258.21
# 6064        55.50         16.26                    0.3        179.06
# 10291        0.00          0.00                    0.3        131.80
# 29          18.56         11.52                    0.3        111.38
# 18130       19.85          8.16                    0.3        119.31
# 5792        14.64          5.76                    0.3         73.20
# 15350        4.40          5.76                    0.3         62.96
# 10302       11.71          5.76                    0.3         70.27
# 2592         0.00          5.76                    0.3         63.06

# %%
# sorting amount by total amoutn from high to low
total_amount_sorted = df.sort_values(by=['total_amount'], ascending=False)['total_amount']
total_amount_sorted.head(20)
# Out:
# 8476     1200.29
# 20312     450.30
# 13861     258.21
# 12511     233.74
# 15474     211.80
# 6064      179.06
# 16379     157.06
# 3582      152.30
# 11269     151.82
# 9280      150.30
# 1928      137.80
# 10291     131.80
# 6708      126.00
# 11608     123.30
# 908       121.56
# 7281      120.96
# 18130     119.31
# 13621     115.94
# 13359     111.95
# 29        111.38
# Name: total_amount, dtype: float64

# %%
total_amount_sorted.tail(20)
# Out:
# 14283      0.31
# 19067      0.30
# 10506      0.00
# 5722       0.00
# 4402       0.00
# 22566      0.00
# 1646      -3.30
# 18565     -3.80
# 314       -3.80
# 5758      -3.80
# 5448      -4.30
# 4423      -4.30
# 10281     -4.30
# 8204      -4.80
# 20317     -4.80
# 11204     -5.30
# 14714     -5.30
# 17602     -5.80
# 20698     -5.80
# 12944   -120.30
# Name: total_amount, dtype: float64

# %%
# understanding payment types
df.payment_type.value_counts()
# Out:
# 1    15265
# 2     7267
# 3      121
# 4       46
# Name: payment_type, dtype: int64

# %%
# understanding  how much average tip is paid by cash and card 

avg_card_tip = df[df.payment_type==1]['tip_amount'].mean()
print(f'The average card tip is: {avg_card_tip}')

avg_cash_tip = df[df.payment_type==2]['tip_amount'].mean()
print(f'The average cash tip is: {avg_cash_tip}')
# Out:
# The average card tip is: 2.7298001965280054
# The average cash tip is: 0.0

# %%
# how many times has a vendor driven
df.VendorID.value_counts()
# Out:
# 2    12626
# 1    10073
# Name: VendorID, dtype: int64

# %%
# mean total amount gained by each vendor 
df.groupby(['VendorID']).agg({'mean'}, numeric_only=True)['total_amount']
# Out:
#                mean
# VendorID
# 1         16.298119
# 2         16.320382

# %%
# filtering data wehre payments are done by card  
card_payment = df[df.payment_type==1]

# filtering the passenger count for credit card payments
card_payment['passenger_count'].value_counts()
# Out:
# 1    10977
# 2     2168
# 5      775
# 3      600
# 6      451
# 4      267
# 0       27
# Name: passenger_count, dtype: int64

# %% [markdown]
# Key observations:
# - There are 27 instances wehre the passenger count was 0.

# %%
# how much avg tip was paid for card payment trips based on passenger count 
card_payment.groupby(['passenger_count']).mean()[['tip_amount']]
# Out:
#                  tip_amount
# passenger_count
# 0                  2.610370
# 1                  2.714681
# 2                  2.829949
# 3                  2.726800
# 4                  2.607753
# 5                  2.762645
# 6                  2.643326

# %% [markdown]
# <h4>2) EDA (Exploratory Data Analysis)  </h4>
# <ul>
#     <li> <b>Goal</b>: Clean data set and create visualization</li>
# <li><b>Understanding the situation:</b> From previous steps we have some basic understanding of the data, important variables, abnormal values in descriptive statistics that require further analysis and variables that might have outliers that need to  be handled.
#  </li>
#  <li><b>Understand the data: </b>Perform EDA on important columns. Find outliers and handle outliers. Some necessary visualizations to show to stakeholders and creation of dashboard to help non technical stakeholders undestand data with accessibility in mind. </li>
#  <li><b>Understanding variables: </b>Leverage insights from previous summary statistics and data examination to guide deeper investigation into key fare-determining variables</li>
#
# </ul>

# %%
# from previous steps : tpep_pickup_datetime and tpep_dropoff_datetime columns are not in datetime format.abs

# changing to datetime 
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  datetime64[ns]
#  3   tpep_dropoff_datetime  22699 non-null  datetime64[ns]
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
#  14  tip_amount             22699 non-null  float64
#  15  tolls_amount           22699 non-null  float64
#  16  improvement_surcharge  22699 non-null  float64
#  17  total_amount           22699 non-null  float64
# dtypes: datetime64[ns](2), float64(8), int64(7), object(1)
# memory usage: 3.1+ MB

# %% [markdown]
# <b>Trip distance</b>

# %%
# box plot for trip distance
plt.figure(figsize=(10,2))
sns.boxplot(data=df, x='trip_distance', fliersize=2)
plt.title('Box plot for trip distance (in miles)')
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.hist(df.trip_distance, bins=range(0,20,1))
plt.xlabel('Trip distance')
plt.ylabel('Number of trips')
plt.title('Histogram of trip distance')
plt.show()

# %% [markdown]
# <b>From the boxplot: </b> we can see that there are many outliers where the trips that are over 6 miles. The data is also skewed to the right with median trip distance being 2 miles.
#
# <b>From the histogram: </b> The observations from the boxplot can be confirmed through the histogram. Majority of trips were the journey of 2 miles. The number of trips fall steeply as the distance increase beyond 2 miles.

# %% [markdown]
# <b>Total amount</b>

# %%
df[['total_amount']].head()
# Out:
#    total_amount
# 0         16.56
# 1         20.80
# 2          8.75
# 3         27.69
# 4         17.80

# %%
# Box plot for total amount
plt.figure(figsize=(10,2))
plt.title('Boxplot of total amount')
sns.boxplot(data=df, x='total_amount',fliersize=2)
plt.show()

# %%
# Histogram for total_amount 
plt.figure(figsize=(10,4))
plt.hist(x=df.total_amount, bins=range(0,100,5))
plt.title('Histogram of total amount')
plt.xlabel("Total Amount")
plt.ylabel('Count')
plt.show()

# %% [markdown]
# <b>From the boxplot: </b> The box plot shows that the data contains many outliers while the trips range from 0 to 20 dollars. It looks like there are instances where where the total amount for the trip was negative.
#
# <b>From the histogram: </b> The histogram shows that the total amount data is highly skewed to the right and most trip costs fell betweem 5 to 15 dollars.

# %%
# finding the instance of negative total amounts
neg_total_amount = df[df.total_amount < 0]
neg_total_amount
# Out:
#        Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 314     105454287         2  2017-12-13 02:02:39   2017-12-13 02:03:08
# 1646     57337183         2  2017-07-05 11:02:23   2017-07-05 11:03:00
# 4423     97329905         2  2017-11-16 20:13:30   2017-11-16 20:14:50
# 5448     28459983         2  2017-04-06 12:50:26   2017-04-06 12:52:39
# 5758       833948         2  2017-01-03 20:15:23   2017-01-03 20:15:39
# 8204     91187947         2  2017-10-28 20:39:36   2017-10-28 20:41:59
# 10281    55302347         2  2017-06-05 17:34:25   2017-06-05 17:36:29
# 11204    58395501         2  2017-07-09 07:20:59   2017-07-09 07:23:50
# 12944    29059760         2  2017-04-08 00:00:16   2017-04-08 23:15:57
# 14714   109276092         2  2017-12-24 22:37:58   2017-12-24 22:41:08
# 17602    24690146         2  2017-03-24 19:31:13   2017-03-24 19:34:49
# 18565    43859760         2  2017-05-22 15:51:20   2017-05-22 15:52:22
# 20317    75926915         2  2017-09-09 22:59:51   2017-09-09 23:02:06
# 20698    14668209         2  2017-02-24 00:38:17   2017-02-24 00:42:05
#
#        passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 314                  6           0.12           1                  N
# 1646                 1           0.04           1                  N
# 4423                 2           0.06           1                  N
# 5448                 1           0.25           1                  N
# 5758                 1           0.02           1                  N
# 8204                 1           0.41           1                  N
# 10281                2           0.00           1                  N
# 11204                1           0.64           1                  N
# 12944                1           0.17           5                  N
# 14714                5           0.40           1                  N
# 17602                1           0.46           1                  N
# 18565                1           0.10           1                  N
# 20317                1           0.24           1                  N
# 20698                1           0.70           1                  N
#
#        PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 314             161           161             3         -2.5   -0.5     -0.5
# 1646             79            79             3         -2.5    0.0     -0.5
# 4423            237           237             4         -3.0   -0.5     -0.5
# 5448             90            68             3         -3.5    0.0     -0.5
# 5758            170           170             3         -2.5   -0.5     -0.5
# 8204            236           237             3         -3.5   -0.5     -0.5
# 10281           238           238             4         -2.5   -1.0     -0.5
# 11204            50            48             3         -4.5    0.0     -0.5
# 12944           138           138             4       -120.0    0.0      0.0
# 14714           164           161             4         -4.0   -0.5     -0.5
# 17602            87            45             4         -4.0   -1.0     -0.5
# 18565           230           163             3         -3.0    0.0     -0.5
# 20317           116           116             4         -3.5   -0.5     -0.5
# 20698            65            25             4         -4.5   -0.5     -0.5
#
#        tip_amount  tolls_amount  improvement_surcharge  total_amount
# 314           0.0           0.0                   -0.3          -3.8
# 1646          0.0           0.0                   -0.3          -3.3
# 4423          0.0           0.0                   -0.3          -4.3
# 5448          0.0           0.0                   -0.3          -4.3
# 5758          0.0           0.0                   -0.3          -3.8
# 8204          0.0           0.0                   -0.3          -4.8
# 10281         0.0           0.0                   -0.3          -4.3
# 11204         0.0           0.0                   -0.3          -5.3
# 12944         0.0           0.0                   -0.3        -120.3
# 14714         0.0           0.0                   -0.3          -5.3
# 17602         0.0           0.0                   -0.3          -5.8
# 18565         0.0           0.0                   -0.3          -3.8
# 20317         0.0           0.0                   -0.3          -4.8
# 20698         0.0           0.0                   -0.3          -5.8

# %%
neg_total_amount.trip_distance.mean()
# Out:
# 0.2578571428571429

# %% [markdown]
# It looks like most trips where we have instances of negative total amount happened with Vendor 2 where the trip distance was 0.25 miles on average. As these are the outliers in the data, these instances could be system errors and need to be investigated further.

# %% [markdown]
# <b>tip_amount</b>

# %%
# boxplot for tip amount
plt.figure(figsize=(10,2))
plt.title('Box plot of Tip Amount')
sns.boxplot(data=df, x='tip_amount', fliersize=2)
plt.show()

# %%
# histogram for tip amount 

plt.figure(figsize=(10,5))
plt.title('Histogram for tip amount')
plt.hist(x=df.tip_amount, bins=range(0,30, 1))
plt.xlabel('tip amount')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# <b>From the boxplot: </b> The box plot shows that there are many outliers in the tip amount columns that need to be addressed.
#
# <b>From the histogram: </b> The histogram shows that majority of tips ranged between 0 and 3 dollars. The data is highly right skewed.

# %% [markdown]
# <b>Tip amount by vendor</b>

# %%
plt.figure(figsize=(10,5))
ax=sns.histplot(data = df, 
                x='tip_amount', 
                hue='VendorID', 
                bins=range(0,21,1),
               palette='pastel',
               multiple='stack')
ax.set_xticks(range(0,30,1))
ax.set_xticklabels(range(0,30,1))
plt.title('Histogram of Tip amount by Vendor')
plt.show()

# %%
df.VendorID.value_counts()
# Out:
# 2    12626
# 1    10073
# Name: VendorID, dtype: int64

# %% [markdown]
# The histogram shows that there is no significant difference in the tips received among both vendors. Vendor 2 has slightly higher number of trips than vendor 1 in the dataset and this proportion is maintained throughout all tip amounts. We will see if the observation is similar on the upper end of the range of tip amount values.

# %%
## upper end of the histogram 
tips_over_six  = df[df.tip_amount > 10]

ax = sns.histplot(data=tips_over_six, 
            x='tip_amount',
            hue='VendorID',  
            multiple='stack', bins=range(10,25,1), 
            palette='pastel')

ax.set_xticks(range(10,25,1))
ax.set_xticklabels(range(10,25,1))
plt.title('Histogram of tip amount by Vendor (tip amount over $10)')
plt.show()

# %% [markdown]
# The proportions are maintained at the higher tip amounts as well with slight difference at the higher extremity but this is not noteworthy due to low sample size at these tip amounts.

# %% [markdown]
# <b>Mean tip by passenger count</b>

# %% [markdown]
# To understand how tips differ by passenger count.

# %%
df.passenger_count.value_counts()
# Out:
# 1    16117
# 2     3305
# 5     1143
# 3      953
# 6      693
# 4      455
# 0       33
# Name: passenger_count, dtype: int64

# %% [markdown]
# Majority of the rides were single occupancy, though there were still nearly 700 rides that had as many as 6 passengers. There are 33 rides with no passenders which needs further investigation. These kinds of trip must be dropped from the data set unless there is some other reasonable explanation for it.

# %%
# calculating mean tip based on passenger count 

mean_tip_passcount = df.groupby(['passenger_count']).mean()[['tip_amount']]
mean_tip_passcount
# Out:
#                  tip_amount
# passenger_count
# 0                  2.135758
# 1                  1.848920
# 2                  1.856378
# 3                  1.716768
# 4                  1.530264
# 5                  1.873185
# 6                  1.720260

# %%
# visalizing the above finding

data = mean_tip_passcount.tail(-1)   # as we dont want 0 passenger data

# original indices of sorted array 
rank = data.tip_amount.argsort()
# print(rank)
pal = sns.color_palette('Greens_d', len(data))
pal = list(pal)

plt.figure(figsize=(12,7))
ax = sns.barplot(hue = data.index,     # getting error for using x in this version of seaborn hence "hue"
                 x = data.index,
                 y = data.tip_amount, 
           palette = np.array(pal[::-1])[rank])

ax.axhline(data.tip_amount.mean(), ls="--", color='red', label='global mean')
ax.legend()
plt.title('Mean tip amount by passenger count')
plt.show()

# %% [markdown]
# Mean tip amount does not vary a lot however it does drop noticeably for 4 passenger rides. However, this sudden drop/fluctuation could also be because rides with four passengers were the least number of rides in the dataset (only 455) as compared to one passenger ride numbers (16117).

# %% [markdown]
# <b> Creating month and day columns </b>

# %%
df["month"] = df.tpep_pickup_datetime.dt.month_name()
df['day'] = df.tpep_pickup_datetime.dt.day_name()

# %% [markdown]
# <b>Total rides by month </b>

# %%
monthly_rides = df.month.value_counts(ascending=True)
monthly_rides
# Out:
# July         1697
# August       1724
# September    1734
# February     1769
# November     1843
# December     1863
# June         1964
# January      1997
# May          2013
# April        2019
# October      2027
# March        2049
# Name: month, dtype: int64

# %%
order_of_month = ['January', 'February', "March", 'April', 'May', "June", "July", "August", "September", "October", "November", "December"]

monthly_rides = monthly_rides.reindex(index=order_of_month)
monthly_rides
# Out:
# January      1997
# February     1769
# March        2049
# April        2019
# May          2013
# June         1964
# July         1697
# August       1724
# September    1734
# October      2027
# November     1843
# December     1863
# Name: month, dtype: int64

# %%
plt.figure(figsize=(10,5))
ax=sns.barplot( x = monthly_rides.index, 
              y = monthly_rides.values, 
              hue = monthly_rides.index)
ax.set_xticklabels(order_of_month)
plt.xticks(rotation=60)
plt.xlabel("Month")
plt.ylabel('Count')
plt.title('Ride count by month')
plt.show()

# %% [markdown]
# The overall number of rides in all month is pretty consistent, with notable dips in the summer months of July, August, Sepetember and also February.

# %% [markdown]
# <b>Total revenue by month</b>

# %%
# to make numbers readable
def readable_num(x):
    if x >= 1e6: 
        s = f"{x*1e-6:.2f}M"
    else: s = f"{x*1e-3:.2f}K"

    return s

# %%
total_monthly_revenue = df.groupby(['month']).agg({'total_amount':"sum"})
total_monthly_revenue = total_monthly_revenue.reindex(index=order_of_month)
total_monthly_revenue.reset_index(inplace=True)

# %%
total_monthly_revenue
# Out:
#         month  total_amount
# 0     January      31735.25
# 1    February      28937.89
# 2       March      33085.89
# 3       April      32012.54
# 4         May      33828.58
# 5        June      32920.52
# 6        July      26617.64
# 7      August      27759.56
# 8   September      28206.38
# 9     October      33065.83
# 10   November      30800.44
# 11   December      31261.57

# %%
# visualize - Total monthly revenue
plt.figure(figsize=(10,6))

ax = sns.barplot(x = total_monthly_revenue.month, 
                 hue= total_monthly_revenue.month,
                y = total_monthly_revenue.total_amount)

for i in range(len(total_monthly.index)):
    plt.text(i-0.4,total_monthly_revenue.total_amount[i]+500,
             total_monthly_revenue.total_amount.apply(readable_num)[i])

plt.title("Total monthly revenue")
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# Total monthly revenue generally follows similar pattern to monthly ride counts. There is a noticeable dip in revenue for the summer month of July, August,  Sepetember and also February.

# %% [markdown]
# <b>Ride count by day</b>

# %%
daily_rides = df.day.value_counts(ascending=True)

order_of_day = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
daily_rides = daily_rides.reindex(order_of_day)
daily_rides
# Out:
# Monday       2931
# Tuesday      3198
# Wednesday    3390
# Thursday     3402
# Friday       3413
# Saturday     3367
# Sunday       2998
# Name: day, dtype: int64

# %%
plt.figure(figsize=(10,5))
ax = sns.barplot(x=daily_rides.index,hue=daily_rides.index, y=daily_rides.values)
for i in range(len(daily_rides.index)):
    plt.text(i-0.3, daily_rides[i]+30, daily_rides.apply(readable_num)[i])
plt.title("Ride count by day")
plt.ylabel('Count')
plt.xlabel("Day")
plt.show()

# %% [markdown]
# The daily ride counts are fairly consistent, with notable dips on Monday and Sunday. The highest ride count is on Friday with 3.41K rides.

# %% [markdown]
# <b>Total revnue by day</b>

# %%
total_day_rev = df.groupby(['day']).agg({'total_amount':'sum'})
total_day_rev = total_day_rev.reindex(order_of_day)
total_day_rev
# Out:
#            total_amount
# day
# Monday         49574.37
# Tuesday        52527.14
# Wednesday      55310.47
# Thursday       57181.91
# Friday         55818.74
# Saturday       51195.40
# Sunday         48624.06

# %%
# barplot for total revenue by day 
plt.figure(figsize=(10,5))

data = total_day_rev.reset_index()
ax = sns.barplot(x=data.day, y=data.total_amount, hue=data.day)

for i in range(len(data.index)):
    plt.text(i-0.3, data.total_amount[i]+600, data.total_amount.apply(readable_num)[i])

ax.set_xticklabels(order_of_day)
ax.set_xlabel('Day')
ax.set_ylabel("Total Revenue")
plt.title("Total Revenue by day")
plt.show()

# %% [markdown]
# The total revenue by day is fairly consistent and has similar distribution to the total ride count by day data. Thursdays have the highest revenue while Monday and Sunday have the least. Eventhough Satuday had similar ride counts to Thursdays, the total revenue is lower than that of Thursday.

# %% [markdown]
# <b>Mean trip distance by drop-off location </b>

# %%
# to get unique locations
df.DOLocationID.nunique()
# Out:
# 216

# %%
distance_by_dropoff = df.groupby('DOLocationID').agg({'trip_distance':'mean'})
distance_by_dropoff = distance_by_dropoff.sort_values(by='trip_distance')
distance_by_dropoff
# Out:
#               trip_distance
# DOLocationID
# 207                1.200000
# 193                1.390556
# 237                1.555494
# 234                1.727806
# 137                1.818852
# ...                     ...
# 51                17.310000
# 11                17.945000
# 210               20.500000
# 29                21.650000
# 23                24.275000
#
# [216 rows x 1 columns]

# %%
plt.figure(figsize=(10,7))
data = distance_by_dropoff.reset_index()
ax = sns.barplot(x = data.DOLocationID, y = data.trip_distance, hue=data.trip_distance, order=data.DOLocationID)

ax.set_xticklabels([])
ax.set_xticks([])
ax.set_xlabel("Drop off location")
ax.set_ylabel("Trip distance")
plt.title("Mean trip distance by Location ID")
plt.show()

# %% [markdown]
# This plot represents the characteristic curve related to the cumulative density function of a normal distribution. In other words, it indicates that the drop-off points are realtively evenly distributed over the terrain.

# %% [markdown]
# To confirm the above conclusion we will do the following experiement:
# 1) Create a sample of coordinated from normal distribution - in this case we will have 1500 pairs of points from a normal ditribution with the mean 10 and standard deviation of 5.
# 2) Calculate the distance between each pair of coordinates (using Euclidean distance formula)
# 3) Group the coordinates by endpoint and calculate the mean distance between that endpoint and all other points it was paired with.
# 4) Plot the mean distance for each unique endpoint.

# %%
# 1. Generate random points on a 2D plane from a normal distribution
test = np.round(np.random.normal(10, 5, (3000, 2)), 1)
midway = int(len(test)/2)  # Calculate midpoint of the array of coordinates
start = test[:midway]      # Isolate first half of array ("pick-up locations")
end = test[midway:]        # Isolate second half of array ("drop-off locations")
test_df = pd.DataFrame(test)
test_df.rename(columns={0:'x', 1: 'y'}, inplace=True)
print(f'test df is : \n{test_df}')

# checking visually
plt.hist(test_df.x, bins=range(-5,30,2))
plt.title('Plot of normal distribution points (test_df) ')
plt.show()

print(f"Midway : {midway}\n \nstart : \n{start}\n\nend : \n{end}")
# Out:
# test df is :
#          x     y
# 0     12.0   7.0
# 1      4.2   6.2
# 2     17.6  22.5
# 3      7.1  15.4
# 4     13.0  18.6
# ...    ...   ...
# 2995   5.9   5.3
# 2996  12.0   3.6
# 2997   7.1  -0.8
# 2998  10.2  13.6
# 2999  10.5  -0.7
#
# [3000 rows x 2 columns]
# Midway : 1500
#
# start :
# [[12.   7. ]
#  [ 4.2  6.2]
#  [17.6 22.5]
#  ...
#  [ 6.9 18.6]
#  [11.3 15.2]
#  [19.3  4.8]]
#
# end :
# [[13.4  8.9]
#  [12.7 11.7]
#  [21.4 15.2]
#  ...
#  [ 7.1 -0.8]
#  [10.2 13.6]
#  [10.5 -0.7]]

# %%
# 2. Calculate Euclidean distances between points in first half and second half
# of array
distances = (start - end)**2           
distances = distances.sum(axis=-1)
distances = np.sqrt(distances)

distances
# Out:
# array([ 2.36008474, 10.12422837,  8.22982381, ..., 19.4010309 ,
#         1.94164878, 10.37737925])

# %%
# 3. Group the coordinates by "drop-off location", compute mean distance
test_df = pd.DataFrame({'start': [tuple(x) for x in start.tolist()],
                   'end': [tuple(x) for x in end.tolist()],
                   'distance': distances})
data = test_df[['end', 'distance']].groupby('end').mean()
data = data.sort_values(by='distance')
data = data.reset_index() 

# Converting the 'end' (tuple) column to string for plottingabs
data['end'] = data['end'].astype(str)

data
# Out:
#                end   distance
# 0     (12.3, 14.7)   0.412311
# 1       (6.6, 9.7)   0.500000
# 2       (8.2, 8.2)   0.632456
# 3      (9.9, 16.4)   0.640312
# 4      (10.6, 6.7)   0.670820
# ...            ...        ...
# 1465  (25.5, -0.1)  24.043294
# 1466    (9.2, 9.5)  24.236543
# 1467  (10.4, -1.1)  24.520400
# 1468   (20.8, 7.2)  24.957564
# 1469  (15.5, 11.0)  24.980793
#
# [1470 rows x 2 columns]

# %%
# 4. Plot the mean distance between each endpoint ("drop-off location") and all points it was paired with
plt.figure(figsize=(14,6))
ax = sns.barplot(x=data.end, hue=data.end,
                 y=data.distance)


ax.set_xticklabels([])
ax.set_xticks([])

ax.set_xlabel('Endpoint')
ax.set_ylabel('Mean distance to all other points')
ax.set_title('Mean distance between points taken randomly from normal distribution')

plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# %% [markdown]
# The curve described by this graph is nearly identical to that of the mean trip distance travelled by each taxi ride to each drop-off location. This shows that the drop-off locations in the taxi dataset are evenly distributed.

# %%
df
# Out:
#        Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0        24870114         2  2017-03-25 08:55:43   2017-03-25 09:09:47
# 1        35634249         1  2017-04-11 14:53:28   2017-04-11 15:19:58
# 2       106203690         1  2017-12-15 07:26:56   2017-12-15 07:34:08
# 3        38942136         2  2017-05-07 13:17:59   2017-05-07 13:48:14
# 4        30841670         2  2017-04-15 23:32:20   2017-04-15 23:49:03
# ...           ...       ...                  ...                   ...
# 22694    14873857         2  2017-02-24 17:37:23   2017-02-24 17:40:39
# 22695    66632549         2  2017-08-06 16:43:59   2017-08-06 17:24:47
# 22696    74239933         2  2017-09-04 14:54:14   2017-09-04 14:58:22
# 22697    60217333         2  2017-07-15 12:56:30   2017-07-15 13:08:26
# 22698    17208911         1  2017-03-02 13:02:49   2017-03-02 13:16:09
#
#        passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                    6           3.34           1                  N
# 1                    1           1.80           1                  N
# 2                    1           1.00           1                  N
# 3                    1           3.70           1                  N
# 4                    1           4.37           1                  N
# ...                ...            ...         ...                ...
# 22694                3           0.61           1                  N
# 22695                1          16.71           2                  N
# 22696                1           0.42           1                  N
# 22697                1           2.36           1                  N
# 22698                1           2.10           1                  N
#
#        PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0               100           231             1         13.0    0.0      0.5
# 1               186            43             1         16.0    0.0      0.5
# 2               262           236             1          6.5    0.0      0.5
# 3               188            97             1         20.5    0.0      0.5
# 4                 4           112             2         16.5    0.5      0.5
# ...             ...           ...           ...          ...    ...      ...
# 22694            48           186             2          4.0    1.0      0.5
# 22695           132           164             1         52.0    0.0      0.5
# 22696           107           234             2          4.5    0.0      0.5
# 22697            68           144             1         10.5    0.0      0.5
# 22698           239           236             1         11.0    0.0      0.5
#
#        tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0            2.76          0.00                    0.3         16.56
# 1            4.00          0.00                    0.3         20.80
# 2            1.45          0.00                    0.3          8.75
# 3            6.39          0.00                    0.3         27.69
# 4            0.00          0.00                    0.3         17.80
# ...           ...           ...                    ...           ...
# 22694        0.00          0.00                    0.3          5.80
# 22695       14.64          5.76                    0.3         73.20
# 22696        0.00          0.00                    0.3          5.30
# 22697        1.70          0.00                    0.3         13.00
# 22698        2.35          0.00                    0.3         14.15
#
#            month       day
# 0          March  Saturday
# 1          April   Tuesday
# 2       December    Friday
# 3            May    Sunday
# 4          April  Saturday
# ...          ...       ...
# 22694   February    Friday
# 22695     August    Sunday
# 22696  September    Monday
# 22697       July  Saturday
# 22698      March  Thursday
#
# [22699 rows x 20 columns]

# %% [markdown]
# <b>Histogram of rides by drop-odd location</b>

# %%
df.DOLocationID.nunique()
# Out:
# 216

# %%
df.DOLocationID.max() - len(set(df.DOLocationID))
# Out:
# 49

# %%
plt.figure(figsize=(16,7))
# DOLocationID column is numeric, so sort in ascending order
sorted_dropoffs = df['DOLocationID'].sort_values()
# Convert to string
sorted_dropoffs = sorted_dropoffs.astype('str')
# Plot
plt.hist(sorted_dropoffs, bins=range(0, df['DOLocationID'].max()+1, 1))
plt.xticks([])
plt.xlabel('Drop-off locations')
plt.title('Histogram of rides by drop-off location', fontsize=16);

# %% [markdown]
# The overall distribution of drop off location is very uneven, a disproportionate number of locations receive the majority of the traffic, while all the rest get relatively few trips. This could be because the high traffic location could be popular tourist attractions or airports, train stations or bus terminals. However, as we do not have the data showing the location of each ID it is hard to know the reason why some areas receive more traffic than the others.

# %%
df['trip_duration'] = df['tpep_dropoff_datetime']-df['tpep_pickup_datetime']
df.trip_duration
# Out:
# 0       0 days 00:14:04
# 1       0 days 00:26:30
# 2       0 days 00:07:12
# 3       0 days 00:30:15
# 4       0 days 00:16:43
#               ...
# 22694   0 days 00:03:16
# 22695   0 days 00:40:48
# 22696   0 days 00:04:08
# 22697   0 days 00:11:56
# 22698   0 days 00:13:20
# Name: trip_duration, Length: 22699, dtype: timedelta64[ns]
